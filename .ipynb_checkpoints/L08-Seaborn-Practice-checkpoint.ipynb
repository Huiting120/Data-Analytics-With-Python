# %% [markdown]
# # Lesson 8 Practice: Seaborn
#
# Use this notebook to follow along with the lesson in the corresponding lesson notebook: [L08-Seaborn-Lesson.ipynb](./L08-Seaborn-Lesson.ipynb).

# %% [markdown]
# ## Instructions
# Follow along with the teaching material in the lesson. Throughout the tutorial sections labeled as "Tasks" are interspersed and indicated with the icon: ![Task](http://icons.iconarchive.com/icons/sbstnblnd/plateau/16/Apps-gnome-info-icon.png). You should follow the instructions provided in these sections by performing them in the practice notebook.  When the tutorial is completed you can turn in the final practice notebook. For each task, use the cell below it to write and test your code.  You may add additional cells for any task as needed or desired.

# %% [markdown]
# ## Task 1a Setup
#
# Import the following packages:
# + seaborn as sns
# + pandas as pd
# + numpy as np
# + matplotlib.pyplot as plt
#
# Activate the `%matplotlib inline` magic.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Task 2a Load Data
#
# + View available datasets by calling `sns.get_dataset_names`.
# + Choose one of those datasets and explore it.

# %% [markdown]
# What is the shape?

# %%
sns.get_dataset_names()
crash_df = sns.load_dataset('car_crashes')
crash_df.shape
# Out:
# (51, 8)

# %% [markdown]
# What are the columns?

# %%
crash_df.columns
# Out:
# Index(['total', 'speeding', 'alcohol', 'not_distracted', 'no_previous',
#        'ins_premium', 'ins_losses', 'abbrev'],
#       dtype='object')

# %% [markdown]
#  What are the data types?

# %%
crash_df.dtypes
# Out:
# total             float64
# speeding          float64
# alcohol           float64
# not_distracted    float64
# no_previous       float64
# ins_premium       float64
# ins_losses        float64
# abbrev             object
# dtype: object

# %% [markdown]
# Are there missing values?

# %%
crash_df.isna().sum()
# Out:
# total             0
# speeding          0
# alcohol           0
# not_distracted    0
# no_previous       0
# ins_premium       0
# ins_losses        0
# abbrev            0
# dtype: int64

# %% [markdown]
# Are there duplicated rows?

# %%
crash_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# For categorical columns find the unique set of categories.

# %%
crash_df.groupby('abbrev').size()
# Out:
# abbrev
# AK    1
# AL    1
# AR    1
# AZ    1
# CA    1
# CO    1
# CT    1
# DC    1
# DE    1
# FL    1
# GA    1
# HI    1
# IA    1
# ID    1
# IL    1
# IN    1
# KS    1
# KY    1
# LA    1
# MA    1
# MD    1
# ME    1
# MI    1
# MN    1
# MO    1
# MS    1
# MT    1
# NC    1
# ND    1
# NE    1
# NH    1
# NJ    1
# NM    1
# NV    1
# NY    1
# OH    1
# OK    1
# OR    1
# PA    1
# RI    1
# SC    1
# SD    1
# TN    1
# TX    1
# UT    1
# VA    1
# VT    1
# WA    1
# WI    1
# WV    1
# WY    1
# dtype: int64

# %% [markdown]
# Is the data tidy?

# %%
crash_df.head()
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
# 3   22.4     4.032    5.824          21.056       21.280       827.34
# 4   12.0     4.200    3.360          10.920       10.680       878.41
#
#    ins_losses abbrev
# 0      145.08     AL
# 1      133.93     AK
# 2      110.35     AZ
# 3      142.39     AR
# 4      165.63     CA

# %% [markdown]
# ## Task 2b Preview Seaborn
#
# Take some time to peruse the Seaborn [example gallery](https://seaborn.pydata.org/examples/index.html).  Indicate which plot types are most interesting to you. Which do you expect will be most useful with current research projects you may be working on?

# %% [raw]
# heatmap, clustermap, violinplot

# %% [markdown]
# ## Task 3a Using `relplot`
#
# Experiment with the `size`, `hue` and `style` semantics by applying them to another example dataset of your choice.
#
# *You should produce three or more plots for this task.*

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'tips',
#  'titanic']

# %%
mpg_df = sns.load_dataset('mpg')
mpg_df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
sns.relplot(x = 'weight', y = 'acceleration', data = mpg_df)

# %%
sns.relplot(x = 'weight', y = 'acceleration', hue = 'origin', data = mpg_df)

# %%
sns.relplot(x = 'weight', y = 'acceleration', hue = 'origin', style = 'cylinders', data = mpg_df)

# %% [markdown]
# ## Task 4a: Explore built-in styles
#
# Using a dataset of your choice, practice creating a plot for each of these different styles:
#
# + darkgrid
# + whitegrid
# + dark
# + white
# + ticks

# %%
sns.set_style('darkgrid')
sns.relplot(x = 'weight', y = 'acceleration', data = mpg_df)

# %%
sns.set_style('dark')
sns.relplot(x = 'weight', y = 'acceleration', data = mpg_df)

# %%
sns.set_style('whitegrid')
sns.relplot(x = 'weight', y = 'acceleration', data = mpg_df)

# %%
sns.set_style('white')
sns.relplot(x = 'weight', y = 'acceleration', data = mpg_df)

# %%
sns.set_style('ticks')
sns.relplot(x = 'weight', y = 'acceleration', data = mpg_df)

# %% [markdown]
# ## Task 4b
#
# Experiment with the style options and palettes introduced above. Create and demonstrate a style of your own using a dataset of your choice.

# %%
my_style = {'figure.facecolor' : 'white',
           'axes.facecolor' : 'black'}
sns.set_style('whitegrid', my_style)
sns.relplot(x = 'weight', y = 'acceleration', hue = 'origin', data = mpg_df, palette = 'bright')

# %%
sns.relplot(x = 'weight', y = 'acceleration', hue = 'origin', data = mpg_df, palette = 'colorblind')

# %%
sns.set()

# %% [markdown]
# ## Task 5a
#
# Examine the [Seaborn gallery](https://seaborn.pydata.org/examples/index.html) and find **two to four plots** types that interest you. Re-create a version of those plots using a different data set (make any other style changes you wish).

# %%
sns.set_style('darkgrid')

# %%
sns.lineplot(x = 'cylinders', y = 'horsepower', hue = 'origin', data = mpg_df)
# Out:
# <AxesSubplot:xlabel='cylinders', ylabel='horsepower'>

# %%
sns.violinplot(x = 'cylinders', y = 'horsepower', hue = 'origin', data = mpg_df)
# Out:
# <AxesSubplot:xlabel='cylinders', ylabel='horsepower'>
